# %% [markdown]
# <a href="https://colab.research.google.com/github/SAAlfaa/Project-1/blob/main/Feminine_Magic_and_Hair_Symbolism_in_Harry_Potter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Analysis Summary
#
# - Female characters in Harry Potter show diverse magical styles:
#   - Ginny: fiery, brave
#   - Luna: intuitive, dreamlike
#   - Molly: nurturing, protective
#   - Bellatrix: chaotic, destructive
#   - Cho: emotional, compassionate
#
# - Hair and beauty keywords symbolize identity, power, and magical alignment.
#
# - Sentiment analysis shows:
#   - Positive language: Luna, Molly, Ginny, Cho
#   - Negative language: Bellatrix
#
# - Digital Humanities allows us to quantify cultural symbolism and gender representation in literature.

# %%
from wordcloud import WordCloud

text = " ".join(df['Keywords'])
wc = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
df['Sentiment'] = df['Keywords'].apply(lambda x: sid.polarity_scores(x)['compound'])

df.plot(x='Character', y='Sentiment', kind='bar', legend=False)
plt.title('Sentiment Score of Magical Keywords by Character')
plt.ylabel('Sentiment (-1 negative, +1 positive)')
plt.show()

# %%
freq_df.head(10).plot(x='Word', y='Frequency', kind='bar', legend=False)
plt.title('Top 10 Keywords Across Female Magic Users')
plt.xlabel('Keyword')
plt.ylabel('Frequency')
plt.show()

# %%
all_words = " ".join(df['Keywords']).split()

word_freq = Counter(all_words)

freq_df = pd.DataFrame(word_freq.items(), columns=['Word', 'Frequency']).sort_values(by='Frequency', ascending=False)
freq_df
# Out:
#             Word  Frequency
# 4           hair          5
# 6          spell          2
# 0           fire          1
# 1           bold          1
# 3         growth          1
# 2   independence          1
# 5         beauty          1
# 7        enchant          1
# 8           moon          1
# 9      intuition          1
# 10          calm          1
# 11       mystery          1
# 12          glow          1
# 13         charm          1
# 14          home          1
# 15        mother          1
# 16        warmth          1
# 17    protection          1
# 18        potion          1
# 19          look          1
# 20         chaos          1
# 21         power          1
# 22       cruelty          1
# 23     obsession          1
# 24          dark          1
# 25         curse          1
# 26         water          1
# 27          love          1
# 28       sadness          1
# 29       clarity          1
# 30         shine          1
# 31     transform          1

# %%
data = {
    'Character': ['Ginny', 'Luna', 'Molly Weasley', 'Bellatrix', 'Cho Chang'],
    'Keywords': [
        'fire bold independence growth hair beauty spell enchant',
        'moon intuition calm mystery hair glow charm',
        'home mother warmth protection hair potion look',
        'chaos power cruelty obsession dark spell curse hair',
        'water love sadness clarity hair shine transform'
    ]
}

df = pd.DataFrame(data)
df
# Out:
#        Character                                           Keywords
# 0          Ginny  fire bold independence growth hair beauty spel...
# 1           Luna        moon intuition calm mystery hair glow charm
# 2  Molly Weasley     home mother warmth protection hair potion look
# 3      Bellatrix  chaos power cruelty obsession dark spell curse...
# 4      Cho Chang    water love sadness clarity hair shine transform

# %%
import pandas as pd

import matplotlib.pyplot as plt

from collections import Counter
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %% [markdown]
# # Feminine Magic and Hair Symbolism in Harry Potter
#
# **Objective:**
# This project explores how female characters in Harry Potter use magic and how hair and beauty are represented as symbols of power, transformation, and identity.
#
# **Scope:**
# We focus on five characters: Ginny, Luna, Molly Weasley, Bellatrix, and Cho Chang. We analyze their dialogues and magical vocabulary related to hair, beauty, and transformation.
#
# **Digital Humanities Approach:**
# Using text analysis, keyword filtering, and visualization, we uncover patterns in language that reveal cultural and gendered symbolism in literature.
