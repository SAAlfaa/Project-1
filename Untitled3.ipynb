# %% [markdown]
# <a href="https://colab.research.google.com/github/SAAlfaa/Project-1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pie chart showing distribution of positive vs negative sentiment
labels = ['Positive', 'Negative']
values = [len(df[df['Sentiment'] > 0]), len(df[df['Sentiment'] < 0])]
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140, colors=['pink','purple'])
plt.title('Overall Sentiment in Female Magical Expression')
plt.show()

# %% [markdown]
# | Character | Sentiment        | Symbolism                                    |
# | --------- | ---------------- | -------------------------------------------- |
# | Ginny     | Positive         | Fire & independence = courage and growth     |
# | Luna      | Positive         | Moon & intuition = inner wisdom              |
# | Molly     | Positive         | Home & protection = maternal magic           |
# | Bellatrix | Negative         | Chaos & cruelty = destructive femininity     |
# | Cho       | Neutral-positive | Water & emotion = empathy and transformation |
#
#
# 💡 Insight:
# Female magic in Harry Potter mirrors emotional archetypes — nurturing, intuitive, destructive, and transformative.
# Hair repeatedly symbolizes connection between identity, power, and emotion.

# %%
df.plot(x='Character', y='Sentiment', kind='bar', color='orchid', legend=False)
plt.title('Sentiment Score of Magical Keywords by Character')
plt.ylabel('Sentiment (-1 = negative, +1 = positive)')
plt.show()

# %%
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()

# Calculate sentiment score for each character’s keywords
df['Sentiment'] = df['Keywords'].apply(lambda x: sid.polarity_scores(x)['compound'])
df
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#        Character                                           Keywords  Sentiment
# 0          Ginny  fire bold independence growth hair beauty spel...     0.7650
# 1           Luna        moon intuition calm mystery hair glow charm     0.6124
# 2  Molly Weasley     home mother warmth protection hair potion look     0.4588
# 3      Bellatrix  chaos power cruelty obsession dark spell curse...    -0.9260
# 4      Cho Chang    water love sadness clarity hair shine transform     0.6124

# %%
# Split all keywords into one list
all_words = " ".join(df['Keywords']).split()

# Count each word’s frequency
word_freq = Counter(all_words)

# Convert to DataFrame for sorting and plotting
freq_df = pd.DataFrame(word_freq.items(), columns=['Word', 'Frequency']).sort_values(by='Frequency', ascending=False)
freq_df.head(10)
# Out:
#            Word  Frequency
# 4          hair          5
# 6         spell          2
# 0          fire          1
# 1          bold          1
# 3        growth          1
# 2  independence          1
# 5        beauty          1
# 7       enchant          1
# 8          moon          1
# 9     intuition          1

# %%
data = {
    'Character': ['Ginny', 'Luna', 'Molly Weasley', 'Bellatrix', 'Cho Chang'],
    'Keywords': [
        'fire bold independence growth hair beauty spell enchant',
        'moon intuition calm mystery hair glow charm',
        'home mother warmth protection hair potion look',
        'chaos power cruelty obsession dark spell curse hair',
        'water love sadness clarity hair shine transform'
    ]
}

df = pd.DataFrame(data)
df
# Out:
#        Character                                           Keywords
# 0          Ginny  fire bold independence growth hair beauty spel...
# 1           Luna        moon intuition calm mystery hair glow charm
# 2  Molly Weasley     home mother warmth protection hair potion look
# 3      Bellatrix  chaos power cruelty obsession dark spell curse...
# 4      Cho Chang    water love sadness clarity hair shine transform

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# ***Feminine Magic and Hair Symbolism in Harry Potter***
#
# 🎯 **Objective**
#
# This project explores how female characters in Harry Potter use magic and how hair and beauty are represented as symbols of power, transformation, and identity.
# By using Digital Humanities techniques, we connect literary interpretation with computational analysis.
#
# 🧾 **Dataset Description**
#
# The dataset focuses on five female characters: **Ginny, Luna, Molly Weasley, Bellatrix, and Cho Chang.**
# Each row includes a list of keywords describing their magical traits, emotions, and symbols related to femininity.
#
# Character	Keywords
#
# 1. Ginny	fire bold independence growth hair beauty spell enchant.
#
# 2. Luna	moon intuition calm mystery hair glow charm
# Molly Weasley	home mother warmth protection hair potion look
#
# 3. Bellatrix	chaos power cruelty obsession dark spell curse hair
#
# 4. Cho Chang	water love sadness clarity hair shine transform

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True
